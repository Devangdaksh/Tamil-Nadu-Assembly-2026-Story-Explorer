# %% [markdown]
# # Tamil nadu Assembly 2016 vs 2026
#
# #### Reproducible analysis.  Data in ../data/.

# %%
from pathlib import Path
import sys
import pandas as pd 

# Since the notebook is inside 'notebook/', its parent is the actual project root
ROOT = Path('.').resolve().parent
sys.path.insert(0, str(ROOT))

from src.load_data import (
    constituency_margins,
    constituency_winners,
    load_results,
    party_vote_share,
    year_comparison,
)

r21, r26 = load_results(2021), load_results(2026)
w21, w26 = constituency_winners(r21), constituency_winners(r26)
margins = constituency_margins(r26)
comparison = year_comparison()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 17
#      13     party_vote_share,
#      14     year_comparison,
#      15 )
#      16
# ---> 17 r21, r26 = load_results(2021), load_results(2026)
#      18 w21, w26 = constituency_winners(r21), constituency_winners(r26)
#      19 margins = constituency_margins(r26)
#      20 comparison = year_comparison()
#
# File ~\Downloads\input_files_for_participants_rpc\atliq-media-to-decode-main\src\load_data.py:27, in load_results(year)
#      25 """Load the election results for a given year."""
#      26 path = DATA_DIR / f'{year}_results.csv'
# ---> 27 df = pd.read_csv(path)
#      28 df["ac_number"] = df["ac_number"].astype(int)
#      29 return df
#
# ...

# %%
pd.DataFrame({
    '2021': w21.party.value_counts(),
    '2026': w26.party.value_counts(),
}).fillna(0).astype(int).loc[['TVK','DMK','AIADMK','INC','BJP','NTK']]

# %%
pd.crosstab(w26.region, w26.party)[['TVK','DMK','AIADMK']]

# %%
print('Under 5% margin:', (margins.margin_pct < 5).sum())
margins.nsmallest(5, 'margin_votes')[['constituency','party','runner_up_party','margin_votes']]

# %%
comparison[comparison.changed].groupby(['party_2021','party_2026']).size().sort_values(ascending=False).head(10)
